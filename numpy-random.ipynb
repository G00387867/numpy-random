# %% [markdown]
# # The numpy.random package ![numpy.png](attachment:numpy.png)
# ***

# %% [markdown]
# ##  _An exploration of numpy.random_

# %% [markdown]
# This is an exploration of the **numpy.random routine** within the **_`NumPy Package`_** as a part of an assessement for the module:
# **_programming for data analysis_**

# %% [markdown]
# ***

# %% [markdown]
# ## Simple random data
# ***

# %%
# importing necessary packages and libraries that might be required.
import numpy as np
rng = np.random.default_rng()
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
plt.style.use("ggplot")

# %% [markdown]
#  - ###  ***integers***

# %% [markdown]
# Return random **integers** from low(inclusive) to high(exclusive), or if endpoint=True, low (inclusive) to high (inclusive).

# %%
x = rng.integers(5, size = 100) #random with out endpoint
x # a list of 100 random integers of the numbers 0, 1 , 2, 3 and 4  generated
# Out:
# array([1, 1, 4, 0, 0, 0, 4, 4, 2, 2, 1, 0, 0, 3, 2, 0, 0, 3, 2, 1, 0, 1,
#        3, 0, 3, 2, 4, 1, 1, 0, 0, 0, 3, 0, 1, 3, 2, 4, 4, 3, 3, 2, 2, 1,
#        3, 3, 4, 4, 1, 0, 0, 1, 4, 4, 2, 1, 3, 3, 1, 3, 2, 3, 3, 2, 3, 4,
#        4, 0, 0, 2, 4, 2, 2, 2, 1, 1, 2, 3, 3, 0, 0, 0, 0, 3, 1, 3, 3, 1,
#        0, 1, 2, 4, 2, 4, 3, 3, 1, 0, 3, 0], dtype=int64)

# %%
# Plotting the generated list x
x = plt.plot(x)
plt.show()

# %% [markdown]
# ***
# > Another example of random integers, where `endpoint = True`

# %%
x = rng.integers(5, size = (2, 4)) #random
x  # A list containing two lists within , each sub-list has four integers ranging from 0 to 4
# Out:
# array([[1, 4, 2, 1],
#        [3, 2, 2, 1]], dtype=int64)

# %%
# %matplotlib inline
plt.plot(x)
plt.show()

# %% [markdown]
# - ### ***random***
# Return random **floats** in the half-open interval [0.0, 1.0).

# %%
x = rng.random(10)
x
# Out:
# array([0.06026847, 0.82035499, 0.70890482, 0.90805805, 0.6494502 ,
#        0.94043163, 0.05455305, 0.04625822, 0.72608329, 0.87199061])

# %%
# plotting the x array

plt.plot(x, "ro")
plt.show()

# %% [markdown]
# - ### ***choice***
# Generates a random sample from a given 1-D array.

# %%
x = rng.choice(10, 50)
x
# Out:
# array([9, 2, 6, 2, 7, 3, 7, 2, 4, 7, 5, 4, 9, 1, 7, 5, 0, 3, 4, 2, 0, 1,
#        2, 1, 7, 1, 8, 6, 4, 8, 7, 7, 6, 6, 4, 3, 8, 9, 3, 3, 5, 6, 0, 3,
#        6, 1, 1, 8, 7, 7], dtype=int64)

# %%
plt.plot(x)
plt.show()

# %%
# using countplot from seaborn for better visualisation
sns.countplot(x)
plt.show()

# %% [markdown]
# **The output is equivalent to the `rng.integers(0, 10, 50)`**

# %%
z = rng.integers(0, 10, 50)
z
# Out:
# array([7, 0, 6, 7, 9, 9, 2, 3, 5, 3, 3, 9, 4, 6, 5, 1, 2, 2, 3, 7, 3, 4,
#        9, 1, 8, 0, 6, 4, 0, 9, 4, 2, 1, 6, 9, 9, 8, 3, 7, 9, 2, 9, 6, 5,
#        5, 6, 1, 3, 6, 4], dtype=int64)

# %%
plt.plot(z)
plt.show()

# %%
# using countplot from seaborn for better visualisation
sns.countplot(z)
plt.show()

# %% [markdown]
# - ### ***bytes***
# Return random bytes.

# %%
x = rng.bytes(10)
x
# Out:
# b"\xaf:\xa4d\xf7'y\x1f+\xa2"

# %% [markdown]
# <br>

# %% [markdown]
# ## **Permutations**

# %% [markdown]
# ***

# %% [markdown]
# - ### ***shuffle***

# %% [markdown]
# - ### ***permutation***

# %% [markdown]
# ## Distributions

# %% [markdown]
# - ### ***uniform***

# %% [markdown]
# p(x) = \frac{1}{b-a}

# %%
x = np.random.default_rng().uniform(0,1000,10000)

# %%
plt.hist(x)
# Out:
# (array([1055., 1031.,  995.,  994.,  917., 1060., 1007.,  966.,  930.,
#         1045.]),
#  array([6.30811876e-02, 1.00045348e+02, 2.00027616e+02, 3.00009883e+02,
#         3.99992150e+02, 4.99974417e+02, 5.99956684e+02, 6.99938951e+02,
#         7.99921219e+02, 8.99903486e+02, 9.99885753e+02]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### ***normal***

# %%
x = np.random.default_rng().normal(0, 0.1, 1000)

# %%
plt.hist(x)
# Out:
# (array([  2.,   9.,  62., 171., 272., 236., 170.,  56.,  20.,   2.]),
#  array([-0.32302424, -0.25744793, -0.19187161, -0.1262953 , -0.06071899,
#          0.00485732,  0.07043363,  0.13600994,  0.20158625,  0.26716256,
#          0.33273888]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Seeds

# %% [markdown]
# ***

# %% [markdown]
# PCG64 VS Mersenne Twister

# %% [markdown]
# where PCG64 outperforms Mersenne Twister

# %% [markdown]
# formulate how the seed reproducable results for the code
# https://numpy.org/doc/stable/reference/random/index.html#

# %% [markdown]
# ## References

# %%
[1]

[2]

[3]

[4]

[5]

[6]

[7]
# Out:
# [7]
