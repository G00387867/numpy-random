# %% [markdown]
# # The numpy.random package ![numpy.png](attachment:numpy.png)
# ***

# %% [markdown]
# ##  _An exploration of numpy.random_

# %% [markdown]
# This is an exploration of the **numpy.random routine** within the **_`NumPy Package`_** as a part of an assessement for the module:
# **_programming for data analysis_**

# %% [markdown]
# ***

# %% [markdown]
# ## Simple random data
# ***

# %%
# importing necessary packages and libraries that might be required.
import numpy as np
rng = np.random.default_rng()
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
plt.style.use("ggplot")

# %% [markdown]
#  - ###  ***integers***

# %% [markdown]
# Return random **integers** from low(inclusive) to high(exclusive), or if endpoint=True, low (inclusive) to high (inclusive).

# %%
x = rng.integers(5, size = 100) #random with out endpoint
x # a list of 100 random integers of the numbers 0, 1 , 2, 3 and 4  generated
# Out:
# array([3, 3, 1, 3, 3, 4, 3, 2, 1, 3, 4, 1, 1, 1, 4, 0, 1, 4, 0, 0, 2, 2,
#        0, 2, 2, 0, 3, 4, 3, 0, 0, 0, 4, 4, 3, 2, 0, 3, 1, 2, 2, 1, 2, 4,
#        4, 1, 3, 4, 0, 1, 2, 3, 3, 3, 2, 0, 3, 0, 1, 0, 0, 0, 1, 2, 1, 3,
#        2, 4, 2, 3, 2, 3, 4, 4, 0, 3, 0, 1, 3, 2, 2, 0, 1, 1, 2, 4, 0, 1,
#        3, 0, 0, 1, 4, 4, 1, 0, 2, 1, 1, 0], dtype=int64)

# %%
# Plotting the generated list x
x = plt.plot(x)
plt.show()

# %% [markdown]
# ***
# > Another example of random integers, where `endpoint = True`

# %%
x = rng.integers(5, size = (2, 4)) #random
x  # A list containing two lists within , each sub-list has four integers ranging from 0 to 4
# Out:
# array([[4, 0, 0, 4],
#        [3, 4, 1, 1]], dtype=int64)

# %%
sns.distplot(x)

# %% [markdown]
# - ### ***random***
# Return random **floats** in the half-open interval [0.0, 1.0).

# %%
x = rng.random(10)
x
# Out:
# array([0.78984304, 0.34140792, 0.9270427 , 0.02116213, 0.23548913,
#        0.58355353, 0.12449634, 0.08126825, 0.66375337, 0.30033152])

# %%
# plotting the x array

plt.plot(x, "ro")
plt.show()

# %% [markdown]
# - ### ***choice***
# Generates a random sample from a given 1-D array.

# %%
x = rng.choice(10, 50)
x
# Out:
# array([4, 4, 5, 4, 3, 7, 4, 0, 5, 2, 0, 7, 0, 9, 6, 1, 4, 3, 9, 6, 2, 2,
#        0, 1, 7, 2, 1, 2, 0, 6, 5, 9, 8, 3, 0, 3, 3, 2, 3, 5, 9, 4, 4, 2,
#        4, 8, 3, 1, 9, 6], dtype=int64)

# %%
plt.plot(x)
plt.show()

# %% [markdown]
# **The output is equivalent to the `rng.integers(0, 10, 50)`**

# %%
x = rng.integers(0, 10, 50)
x
# Out:
# array([5, 3, 8, 8, 2, 5, 1, 8, 5, 0, 8, 2, 2, 7, 9, 4, 6, 4, 2, 2, 4, 2,
#        2, 8, 9, 2, 3, 4, 5, 6, 7, 4, 2, 0, 6, 7, 4, 6, 9, 7, 9, 9, 0, 4,
#        6, 7, 4, 5, 3, 7], dtype=int64)

# %%
plt.plot(x)
plt.show()

# %% [markdown]
# - ### ***bytes***
# Return random bytes.

# %%
x = rng.bytes(10)
x
# Out:
# b'U\x8am\xafl\x19\xa3\xd6]\xdd'

# %% [markdown]
# <br>

# %% [markdown]
# ## **Permutations**

# %% [markdown]
# ***

# %% [markdown]
# - ### ***shuffle***

# %% [markdown]
# - ### ***permutation***

# %% [markdown]
# ## Distributions

# %% [markdown]
# ### ***uniform***

# %% [markdown]
# p(x) = \frac{1}{b-a}

# %%
x = np.random.default_rng().uniform(0,1000,10000)

# %%
plt.hist(x)
# Out:
# (array([ 990., 1030.,  994.,  986., 1044., 1000.,  992.,  990., 1017.,
#          957.]),
#  array([5.41592772e-02, 1.00047723e+02, 2.00041286e+02, 3.00034849e+02,
#         4.00028412e+02, 5.00021975e+02, 6.00015539e+02, 7.00009102e+02,
#         8.00002665e+02, 8.99996228e+02, 9.99989792e+02]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### ***normal***

# %%
x = np.random.default_rng().normal(0, 0.1, 1000)

# %%
plt.hist(x)
# Out:
# (array([  5.,  20.,  57., 178., 271., 246., 155.,  53.,  12.,   3.]),
#  array([-0.34933256, -0.27915497, -0.20897739, -0.1387998 , -0.06862222,
#          0.00155536,  0.07173295,  0.14191053,  0.21208811,  0.2822657 ,
#          0.35244328]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Seeds

# %% [markdown]
# ***

# %% [markdown]
# PCG64 VS Mersenne Twister

# %% [markdown]
# where PCG64 outperforms Mersenne Twister

# %% [markdown]
# formulate how the seed reproducable results for the code
# https://numpy.org/doc/stable/reference/random/index.html#

# %% [markdown]
# ## References

# %%
[1]

[2]

[3]

[4]

[5]

[6]

[7]
# Out:
# [7]
